# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = pd.read_excel("Copia di BIBLIOTECA_al_22_marzo_2024(1).xlsx")
file
# Out:
#        selezione                                               Arg.  N.1  \
# 0            NaN                                                 30    1
# 1            NaN                                                 30    2
# 2            NaN                                                 30    3
# 3            NaN                                                 30    4
# 4            NaN                                                 30    5
# ...          ...                                                ...  ...
# 11183        NaN                                                NaN  NaN
# 11184        NaN                                                NaN  NaN
# 11185        NaN                                                NaN  NaN
# 11186        NaN                                                NaN  NaN
# 11187        NaN  ATTENZIONE, ULTIMA PAGINA COON I BORDI (fare c...  NaN
#
#         N.2 Unnamed: 4                                        TITOLO  \
# ...

# %%
file.columns
# Out:
# Index(['selezione', 'Arg.', 'N.1', 'N.2', 'Unnamed: 4', 'TITOLO', 'BIBLIO',
#        'N.INV.', 'non presente in scaffale a Maggio 2022', 'COLORE',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
#        'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49',
#        'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53',
#        'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57',
# ...

# %%
colonne = ["Arg.","N.1","Unnamed: 4","TITOLO","BIBLIO","N.INV.","COLORE"]

# %%
data = file[colonne]
data
# Out:
#                                                     Arg.  N.1 Unnamed: 4  \
# 0                                                     30    1      AA.VV
# 1                                                     30    2      AA.VV
# 2                                                     30    3      AA.VV
# 3                                                     30    4      AA.VV
# 4                                                     30    5      AA.VV
# ...                                                  ...  ...        ...
# 11183                                                NaN  NaN        NaN
# 11184                                                NaN  NaN        NaN
# 11185                                                NaN  NaN        NaN
# 11186                                                NaN  NaN        NaN
# 11187  ATTENZIONE, ULTIMA PAGINA COON I BORDI (fare c...  NaN        NaN
#
#                                              TITOLO       BIBLIO N.INV. COLORE
# ...

# %%
selected_data_2 =  data.dropna(subset=['COLORE'])

# Cerca l'acronimo "V" nella colonna del colore
risultati = selected_data_2[selected_data_2['COLORE'].str.contains('V')]
risultati
# Out:
#       Arg.  N.1          Unnamed: 4  \
# 83     100   37            VOLTAIRE
# 88     100   42  ILLUMINATI AUGUSTO
# 117    100   73    CASANOVA GIACOMO
# 122    100   78    HARRIS THOMAS A.
# 124    100   80  MANTOVANI GIUSEPPE
# ...    ...  ...                 ...
# 11081   Nr  518         S. CONFORTI
# 11082   Nr  519          S. GARDNER
# 11083   Nr  520          R. LAPPERT
# 11084   Nr  521          S. BERTOLA
# 11085   Nr  522           A. PELLAI
#
#                                              TITOLO       BIBLIO N.INV. COLORE
# 83                        Trattato Sulla Tolleranza  B1_Centrale   2403      V
# 88                            Jean Jacques Rousseau  B1_Centrale   3022      V
# 117                              Pensieri Libertini  B1_Centrale   8739      V
# 122                            Io Sono Ok,Tu Sei Ok  B1_Centrale   8675      V
# 124    Qualita' (La) Dell'Interazione Uomo-Computer  B1_Centrale   9423      V
# ...

# %%
selected_data = risultati.copy()
selected_data.dropna(inplace=True)

# %%
# tabella con tutti i libri verdi
selected_data
# Out:
#      Arg.  N.1             Unnamed: 4  \
# 83    100   37               VOLTAIRE
# 88    100   42     ILLUMINATI AUGUSTO
# 117   100   73       CASANOVA GIACOMO
# 122   100   78       HARRIS THOMAS A.
# 124   100   80     MANTOVANI GIUSEPPE
# ...   ...  ...                    ...
# 8337   Nr  500     MANZONI ALESSANDRO
# 8338   Nr  501        ALIGHIERI DANTE
# 8339   Nr  502  MAZZAFERRO ALESSANDRO
# 8340   Nr  503         VERGA GIOVANNI
# 8341   Nr  504      PAPESCHI MARCELLA
#
#                                             TITOLO       BIBLIO N.INV. COLORE
# 83                       Trattato Sulla Tolleranza  B1_Centrale   2403      V
# 88                           Jean Jacques Rousseau  B1_Centrale   3022      V
# 117                             Pensieri Libertini  B1_Centrale   8739      V
# 122                           Io Sono Ok,Tu Sei Ok  B1_Centrale   8675      V
# 124   Qualita' (La) Dell'Interazione Uomo-Computer  B1_Centrale   9423      V
# ...

# %%
selected_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 887 entries, 83 to 8341
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Arg.        887 non-null    object
#  1   N.1         887 non-null    object
#  2   Unnamed: 4  887 non-null    object
#  3   TITOLO      887 non-null    object
#  4   BIBLIO      887 non-null    object
#  5   N.INV.      887 non-null    object
#  6   COLORE      887 non-null    object
# dtypes: object(7)
# memory usage: 55.4+ KB

# %%
selected_data.to_csv('verdi.csv', index=False)
